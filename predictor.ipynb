# %%
import numpy as np
import bottleneck
import pandas as pd
from pandas import DataFrame, read_csv
from bokeh.models import ColumnDataSource, Select
from bokeh.layouts import widgetbox, row, column, layout
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file, curdoc
from bokeh.plotting import figure
from sklearn import cluster, datasets, mixture
from sklearn.cluster import KMeans,DBSCAN,Birch
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.linear_model import Lasso, Ridge
from sklearn.cluster import KMeans,DBSCAN,Birch

def label_encoding(df,df2):
    #select columns with categorical values
    obj_df = df.select_dtypes(include=['object']).copy()
    #checking for missing values
    miss = obj_df[obj_df.isnull().any(axis=1)]
    #print(miss)
    
    #label  and store in df2
    for item in list(obj_df.columns):
        obj_df[item] = obj_df[item].astype('category')
        df2[item]=obj_df[item].cat.codes

def KMeansclustering(df2,features_selected,clusters):
    model=KMeans(n_clusters=clusters,random_state=0)
    model_fit = model.fit_predict(df2[features_selected])
    return model

def KNN_predictor(x_train,y_train,neighbours):
    clf = KNeighborsClassifier(n_neighbors=neighbours)
    clf = clf.fit(x_train,y_train)
    return clf

def get_top_k_corr_attributes(arr,k):
    array = np.array(arr)
    array = [abs(number) for number in array]
    array = np.array(arr)
    temp = bottleneck.argpartition(-array, k+1)[:k+1]
    temp = np.array(temp)
    temp = temp[0]
    top_k_corr_attr = temp[:k+1]
    return top_k_corr_attr

#read the data
df = pd.read_csv('nutrition_raw_anonymized_data.csv')
print (df.shape)
df2 = df.copy()
#convert category data tp binary data
label_encoding(df,df2)

#list of all the columns    
attribute_list= (list(df2.columns))


#compute correlation matrix
corr_mat = df2.corr() 
#corr_mat[1:2] gives correlations for cancer
n_top_attributes = 10
#select top correlated attributes for Cancer
corr_attr_list = get_top_k_corr_attributes(corr_mat[1:2],n_top_attributes)
features_index = corr_attr_list
#get list of top features in string list format
features_list = df2.columns[features_index]

#slice the dataset for training
db = df2[features_list]
x_train = db.loc[:40,:]
y_train = df2.loc[:40,attribute_list[1]]
print (x_train.shape,y_train.shape)
#model for prediction (KNN classifier)
clf = KNN_predictor(x_train,y_train,3)
x_test =   db.loc[:,:]
y_hat = clf.predict(x_test)
y_hat = list(y_hat)

#plot to visualise predictions
x1=df2[features_list[1]]
y1=df2[features_list[2]]
a=figure(plot_height=500, plot_width=700, title='KNN for Cancer')

actual_data_yes = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==1],
                                             y=y1.loc[df2['cancer']==1]))
actual_data_no = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==0],
                                             y=y1.loc[df2['cancer']==0]))
a.square('x','y',fill_color='green',line_color='green',source=actual_data_no,legend='Actual Not cancer',
         alpha=0.4,size=10)
a.circle('x','y',fill_color='firebrick',line_color='firebrick',source=actual_data_yes, legend='Actual Yes cancer',
         alpha=0.4,size=10)

#get indices of predicted values for Cancer=yes, Cancer=No
indices_yes = [i for i, x in enumerate(y_hat) if x == 1]
indices_no = [i for i, x in enumerate(y_hat) if x == 0]

predict_data_yes = ColumnDataSource(data=dict(x=x1.loc[indices_yes],
                                             y=y1.loc[indices_yes]))
predict_data_no = ColumnDataSource(data=dict(x=x1.loc[indices_no],
                                             y=y1.loc[indices_no]))
a.diamond('x','y',fill_color='blue',line_color='blue',source=predict_data_no,legend='Predicted Not cancer',
          fill_alpha=1,size=5)
a.triangle('x','y',fill_color='firebrick',line_color='firebrick',source=predict_data_yes, legend='Predicted Yes cancer', 
          fill_alpha=1,size=5)

a.xaxis.axis_label = features_list[1]
a.yaxis.axis_label = features_list[2]
show(a)



def get_colors(model):
    colors=[]
    for i in model.labels_:
        if i==0:
            colors.append('red')
        if i==1:
            colors.append('blue')
    return colors

def stack_bar_cancer(df2,attr1):
    categories=[]
    cancer_yes=[]
    cancer_no=[]
    for name,item in (df2.groupby([attr1])):
        categories.append(name)
        cancer_yes.append(len(item.loc[df2['cancer']==1]))
        cancer_no.append(len(item.loc[df2['cancer']==0]))

    cncer = ['yes', 'no']

    actualdata_cancer = {attr1 : categories,
           'yes'   : cancer_yes,
           'no'   : cancer_no,
           }
    
    r = figure(x_range=categories, plot_height=250,plot_width=300, title="Cancer")
    r.vbar_stack(['yes','no'], x=attr1, width=0.5, color=['red','blue'], source=ColumnDataSource(actualdata_cancer),
                legend=["%s " % x for x in ['yes','no']])
    #r.vbar_stack(['yes','no'],x='cat', width=0.9, color=GnBu3, source=ColumnDataSource(actualdata2))
    r.ygrid.grid_line_color = None
    r.xaxis.axis_label = attr1+ str('  (0-No\n 1-Yes)')
    r.legend.location='top_center'
    show(r)
    return r

def stack_bar_diabetes(df2,attr1):
    categories=[]
    diabetes_yes=[]
    diabetes_no=[]
    for name,item in (df2.groupby([attr1])):
        categories.append(name)
        diabetes_yes.append(len(item.loc[df2['diabetes']==1]))
        diabetes_no.append(len(item.loc[df2['diabetes']==0]))

    actualdata_diabetes = {attr1 : categories,
           'yes'   : diabetes_yes,
           'no'   : diabetes_no,
           }
    
    q = figure(x_range=categories, plot_height=250,plot_width=300, title="Diabetes")
    q.vbar_stack(['yes','no'], x=attr1, width=0.5, color=['red','blue'], source=ColumnDataSource(actualdata_diabetes),
                legend=["%s " % x for x in ['yes','no']])
    #r.vbar_stack(['yes','no'],x='cat', width=0.9, color=GnBu3, source=ColumnDataSource(actualdata2))
    q.ygrid.grid_line_color = None
    q.legend.location='top_center'
    q.xaxis.axis_label = attr1 + str('  (0-No\n 1-Yes)')
    show(q)
    return q
    
def stack_bar_heart_disease(df2,attr1):
    categories=[]
    heart_disease_yes=[]
    heart_disease_no=[]
    for name,item in (df2.groupby([attr1])):
        categories.append(name)
        heart_disease_yes.append(len(item.loc[df2['heart_disease']==1]))
        heart_disease_no.append(len(item.loc[df2['heart_disease']==0]))

    actualdata_heart_disease = {attr1 : categories,
           'yes'   : heart_disease_yes,
           'no'   : heart_disease_no,
           }
    
    s = figure(x_range=categories, plot_height=250,plot_width=300, title="Heart Disease")
    s.vbar_stack(['yes','no'], x=attr1, width=0.5, color=['red','blue'], source=ColumnDataSource(actualdata_heart_disease),
                legend=["%s " % x for x in ['yes','no']])
    #r.vbar_stack(['yes','no'],x='cat', width=0.9, color=GnBu3, source=ColumnDataSource(actualdata2))
    s.ygrid.grid_line_color = None
    s.xaxis.axis_label = attr1+ str('  (0-No\n 1-Yes)')
    s.legend.location='top_center'
    show(s)
    return s
    


r=stack_bar_cancer(df2,'dog')
q=stack_bar_diabetes(df2,'cat')
s=stack_bar_heart_disease(df2,'diabetes')

#KMeans clustering
model = KMeansclustering(df2,features_list,2)
colorKMeans = get_colors(model)
#plot
p=figure(plot_height=200, plot_width=500, title='KMeans')
actual_data1 = ColumnDataSource(data=dict(x=df2.loc[:,attribute_list[1]],y=df2.loc[:,attribute_list[2]], colors=colorKMeans))
p.circle('x','y',fill_color='colors',line_color='colors',source=actual_data1)
p.xaxis.axis_label = attribute_list[1]
p.yaxis.axis_label = attribute_list[2]

#widgets
x_attribute_select_stackedbars = Select(value='Cancer',
                          title='Select X attribute:',
                          width=200,
                          options=list(df.select_dtypes(include=['object']).columns))

x_attribute_select = Select(value='Cancer',
                          title='Select X attribute:',
                          width=200,
                          options=attribute_list)

y_attribute_select = Select(value='Heart Disease',
                          title='Select Y attribute:',
                          width=200,
                          options=attribute_list)

x_attribute_predictor = Select(value=features_list[0],
                          title='Select X attribute:',
                          width=200,
                          options=list(features_list))
y_attribute_predictor = Select(value=features_list[1],
                          title='Select Y attribute:',
                          width=200,
                          options=list(features_list))



#callbacks
def update_x_attribute_stackedbars(attrname,old,new):
    attr_new = x_attribute_select_stackedbars.value
    print (attr_new)

    r=stack_bar_cancer(df2,attr_new)
    q=stack_bar_diabetes(df2,attr_new)
    s=stack_bar_heart_disease(df2,attr_new)
    l=layout([
    [row(r,q)],
    [row(s)],
    [row(x_attribute_select_stackedbars)],
    [row(p)],
    [row(x_attribute_select,y_attribute_select)]
         ])
    curdoc().add_root(l)
    
def update_x_attribute_predictor(attrname,old,new):
    x1=df2[x_attribute_predictor.value]
    y1=df2[y_attribute_predictor.value]
    a.xaxis.axis_label = x_attribute_predictor.value
    actual_data_yes = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==1],
                                             y=y1.loc[df2['cancer']==1]))
    actual_data_no = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==0],
                                             y=y1.loc[df2['cancer']==0]))
    predict_data_yes = ColumnDataSource(data=dict(x=x1.loc[indices_yes],y=y1.loc[indices_yes]))
    predict_data_no = ColumnDataSource(data=dict(x=x1.loc[indices_no],y=y1.loc[indices_no]))
    
    a.square('x','y',fill_color='green',line_color='green',source=actual_data_no,legend='Actual Not cancer',
         alpha=0.4,size=10)
    a.circle('x','y',fill_color='firebrick',line_color='firebrick',source=actual_data_yes, legend='Actual Yes cancer',
         alpha=0.4,size=10)
    a.diamond('x','y',fill_color='blue',line_color='blue',source=predict_data_no,legend='Predicted Not cancer',fill_alpha=1,size=5)
    a.triangle('x','y',fill_color='firebrick',line_color='firebrick',source=predict_data_yes, legend='Predicted Yes cancer', fill_alpha=1,size=5)

def update_y_attribute_predictor(attrname,old,new):
    x1=df2[x_attribute_predictor.value]
    y1=df2[y_attribute_predictor.value]
    a.yaxis.axis_label = y_attribute_predictor.value
    actual_data_yes = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==1],
                                             y=y1.loc[df2['cancer']==1]))
    actual_data_no = ColumnDataSource(data=dict(x=x1.loc[df2['cancer']==0],
                                             y=y1.loc[df2['cancer']==0]))
    predict_data_yes = ColumnDataSource(data=dict(x=x1.loc[indices_yes],y=y1.loc[indices_yes]))
    predict_data_no = ColumnDataSource(data=dict(x=x1.loc[indices_no],y=y1.loc[indices_no]))

    a.square('x','y',fill_color='green',line_color='green',source=actual_data_no,legend='Actual Not cancer',
         alpha=0.4,size=10)
    a.circle('x','y',fill_color='firebrick',line_color='firebrick',source=actual_data_yes, legend='Actual Yes cancer',
         alpha=0.4,size=10)
    a.diamond('x','y',fill_color='blue',line_color='blue',source=predict_data_no,legend='Predicted Not cancer',fill_alpha=1,size=5)
    a.triangle('x','y',fill_color='firebrick',line_color='firebrick',source=predict_data_yes, legend='Predicted Yes cancer', fill_alpha=1,size=5)

    
def update_x_attribute(attrname,old,new):
    selected_x_attribute_list=df2.loc[:,x_attribute_select.value]
    selected_y_attribute_list=df2.loc[:,y_attribute_select.value]
    p.xaxis.axis_label = x_attribute_select.value   
    actual_data1.data = dict(x=selected_x_attribute_list,y=selected_y_attribute_list,colors=colorKMeans)

def update_y_attribute(attrname,old,new):
    selected_x_attribute_list=df2.loc[:,x_attribute_select.value]
    selected_y_attribute_list=df2.loc[:,y_attribute_select.value]
    p.yaxis.axis_label = y_attribute_select.value   
    actual_data1.data = dict(x=selected_x_attribute_list,y=selected_y_attribute_list,colors=colorKMeans)
    
x_attribute_select.on_change('value', update_x_attribute)
y_attribute_select.on_change('value', update_y_attribute)
x_attribute_select_stackedbars.on_change('value',update_x_attribute_stackedbars)
x_attribute_predictor.on_change('value',update_x_attribute_predictor)
y_attribute_predictor.on_change('value',update_y_attribute_predictor)

#show
l=layout([
    [row(r,q)],
    [row(s)],
    [row(x_attribute_select_stackedbars)],
    [row(p)],
    [row(x_attribute_select)],[row(y_attribute_select)],
    [row(a)],
    [row(x_attribute_predictor)],[row(y_attribute_predictor)]
         ])
curdoc().add_root(l)
# Out:
# (54, 1093)
# (41, 7) (41,)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f744dcdf-d15c-40af-9323-fb9d85d75fc8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f744dcdf-d15c-40af-9323-fb9d85d75fc8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f744dcdf-d15c-40af-9323-fb9d85d75fc8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f744dcdf-d15c-40af-9323-fb9d85d75fc8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3cc8fdf-db3b-4465-932a-838cee611be1":{"roots":{"references":[{"attributes":{"callback":null},"id":"973d4b11-9b8c-434c-bbca-232dfb8f2c15","type":"DataRange1d"},{"attributes":{},"id":"9175e9ba-524c-4483-bb1c-e2080c3132ec","type":"LinearScale"},{"attributes":{"source":{"id":"02d44372-0056-48f7-9527-49d2f5619ad6","type":"ColumnDataSource"}},"id":"81590e8f-4dac-4a74-a584-eed3e83ecd1c","type":"CDSView"},{"attributes":{"callback":null},"id":"3912c925-fb46-4d4b-9714-3bccb274a8c1","type":"DataRange1d"},{"attributes":{"source":{"id":"bee23577-b63b-4a6f-a372-7bcc6daeb4ae","type":"ColumnDataSource"}},"id":"b901e385-1619-45c3-b3b8-75667a16cea4","type":"CDSView"},{"attributes":{},"id":"84feed76-9958-481d-aa05-ee4493646ff8","type":"SaveTool"},{"attributes":{"source":{"id":"1aa15161-82bf-465a-a6bb-5cb22b90903b","type":"ColumnDataSource"}},"id":"50ff0a31-83e5-44e5-bc94-12217ca36050","type":"CDSView"},{"attributes":{"dimension":1,"plot":{"id":"ed92fd89-d0b6-42f5-84b6-4a8acf39484c","subtype":"Figure","type":"Plot"},"ticker":{"id":"a3ec4259-e25e-411f-acd5-0e8662f62938","type":"BasicTicker"}},"id":"004ca634-1512-4a26-a8a4-ebe138400e3a","type":"Grid"},{"attributes":{},"id":"11f9c12e-4ebe-4a47-a2ea-8d522175442c","type":"ResetTool"},{"attributes":{"data_source":{"id":"1aa15161-82bf-465a-a6bb-5cb22b90903b","type":"ColumnDataSource"},"glyph":{"id":"62b3b970-ba82-4ab8-964a-6b5f1a51ba11","type":"Diamond"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"587fd237-da90-4be2-8b86-fbcac765c83e","type":"Diamond"},"selection_glyph":null,"view":{"id":"50ff0a31-83e5-44e5-bc94-12217ca36050","type":"CDSView"}},"id":"9e7b137c-e738-4fed-b1ba-fa29106b90da","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[26]},"y":{"__ndarray__":"","dtype":"float64","shape":[26]}}},"id":"bee23577-b63b-4a6f-a372-7bcc6daeb4ae","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Actual Yes cancer"},"renderers":[{"id":"6130ae89-6ddc-4f97-b454-7ba5dd4bcdeb","type":"GlyphRenderer"}]},"id":"fe62909a-dabf-4eaf-818a-618de218cc52","type":"LegendItem"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"62b3b970-ba82-4ab8-964a-6b5f1a51ba11","type":"Diamond"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f3124eb-c9a2-4031-b143-7156ac64ec68","type":"Circle"},{"attributes":{"plot":null,"text":"KNN"},"id":"9effa665-b230-42cd-a930-6f825cd199f6","type":"Title"},{"attributes":{},"id":"c36bfd4e-ab19-4e51-8692-2387431e2ef7","type":"BasicTicker"},{"attributes":{"below":[{"id":"8ee35206-ed36-42a3-a422-95d8fbf2eb7d","type":"LinearAxis"}],"left":[{"id":"c62da399-3f1e-4aef-a31e-b5bd309c5929","type":"LinearAxis"}],"plot_height":500,"plot_width":700,"renderers":[{"id":"8ee35206-ed36-42a3-a422-95d8fbf2eb7d","type":"LinearAxis"},{"id":"b19ee216-aba2-41fc-bf10-f55bfd7b97b5","type":"Grid"},{"id":"c62da399-3f1e-4aef-a31e-b5bd309c5929","type":"LinearAxis"},{"id":"004ca634-1512-4a26-a8a4-ebe138400e3a","type":"Grid"},{"id":"7379a488-be00-412d-b3fc-54f92675d4ec","type":"BoxAnnotation"},{"id":"f76c3b7a-f592-414d-8f88-2377a154049e","type":"Legend"},{"id":"8a1a384e- ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="643163c1-f7b0-4311-aeb6-cbf2e644eb27"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("643163c1-f7b0-4311-aeb6-cbf2e644eb27");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("643163c1-f7b0-4311-aeb6-cbf2e644eb27");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '643163c1-f7b0-4311-aeb6-cbf2e644eb27' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b06d4b2b-f353-407a-8cde-33eda244aa01":{"roots":{"references":[{"attributes":{"fields":["yes"]},"id":"f88c08e8-23b8-40ea-b770-01ec736b6796","type":"Stack"},{"attributes":{"fields":["yes","no"]},"id":"46489b62-fd95-4ff1-abe8-94d65cb5c66f","type":"Stack"},{"attributes":{},"id":"9fafd893-2e2c-4646-80fb-3802c91c3d5f","type":"LinearScale"},{"attributes":{"bottom":{"expr":{"id":"f88c08e8-23b8-40ea-b770-01ec736b6796","type":"Stack"}},"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"top":{"expr":{"id":"46489b62-fd95-4ff1-abe8-94d65cb5c66f","type":"Stack"}},"width":{"value":0.5},"x":{"field":"diabetes"}},"id":"1fb69949-9705-4934-b155-5c31d71bbdca","type":"VBar"},{"attributes":{"data_source":{"id":"fbca515e-2a40-4c46-bdf2-681fc9d9f099","type":"ColumnDataSource"},"glyph":{"id":"22c1cc73-783c-4bb0-af56-82beee6e28b0","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c2bb0031-c198-449d-ae19-0a769f4a7469","type":"VBar"},"selection_glyph":null,"view":{"id":"cead39fe-28a8-48fe-989b-b656a7490f6f","type":"CDSView"}},"id":"27fc1ad6-8c1f-4953-9d53-9d70b28e3d80","type":"GlyphRenderer"},{"attributes":{"bottom":{"expr":{"id":"f88c08e8-23b8-40ea-b770-01ec736b6796","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"46489b62-fd95-4ff1-abe8-94d65cb5c66f","type":"Stack"}},"width":{"value":0.5},"x":{"field":"diabetes"}},"id":"1ba9ef36-77d2-4da8-bf4b-867360a38d63","type":"VBar"},{"attributes":{"source":{"id":"fbca515e-2a40-4c46-bdf2-681fc9d9f099","type":"ColumnDataSource"}},"id":"cead39fe-28a8-48fe-989b-b656a7490f6f","type":"CDSView"},{"attributes":{"data_source":{"id":"fbca515e-2a40-4c46-bdf2-681fc9d9f099","type":"ColumnDataSource"},"glyph":{"id":"1fb69949-9705-4934-b155-5c31d71bbdca","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1ba9ef36-77d2-4da8-bf4b-867360a38d63","type":"VBar"},"selection_glyph":null,"view":{"id":"975b484d-bff1-4832-8e41-117fbc3734f0","type":"CDSView"}},"id":"6e57cba2-dd3c-4925-8cf9-46e5822c5906","type":"GlyphRenderer"},{"attributes":{"bottom":{"expr":{"id":"88be1dd4-1be4-4a82-bd79-005fb9ba6d09","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"db62a556-5ec0-4d07-941f-d7b5faefbe33","type":"Stack"}},"width":{"value":0.5},"x":{"field":"diabetes"}},"id":"c2bb0031-c198-449d-ae19-0a769f4a7469","type":"VBar"},{"attributes":{"plot":{"id":"6bbf8364-4882-4062-8c4c-8cec741b4517","subtype":"Figure","type":"Plot"},"ticker":{"id":"3718257b-3b18-4a88-8545-ccb630d6e8ae","type":"BasicTicker"}},"id":"9ad41859-bc57-46cf-b0ac-d7b3b36ada17","type":"Grid"},{"attributes":{"items":[{"id":"ab6612c7-d210-4724-be45-fde37b4517fa","type":"LegendItem"},{"id":"b12c4bb3-b36d-4160-b845-23fa5809a8d6","type":"LegendItem"}],"location":"top_center","plot":{"id":"6bbf8364-4882-4062-8c4c-8cec741b4517","subtype":"Figure","type":"Plot"}},"id":"6ace0c62-09fd-45d6-88df-95b48fd36e38","type":"Legend"},{"attributes":{},"id":"7affb349-e5a9-427a-8eaa-1286481ff828","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["diabetes","yes","no"],"data":{"diabetes":[0,1],"no":[21,5],"yes":[18,10]}},"id":"fbca515e-2a40-4c46-bdf2-681fc9d9f099","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b9bd3599-3738-413a-8645-ba61ccf3c85b","type":"BoxAnnotation"}},"id":"768e7e57-fcef-4b55-9ef1-40ca939ea479","type":"BoxZoomTool"},{"attributes":{},"id":"d6c0f364-07a6-4f5b-8de9-9dac44575edc","type":"HelpTool"},{"attributes":{},"id":"80b287a6-c222-4cf3-8b47-53f9d474be5c","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"6bbf8364-4882-4062-8c4c-8cec741b4517","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a797eec-5866-4c24-ac4e-86251c165b4f","type":"BasicTicker"}},"id":"0347e646-914b-4072-9809-d2239b6e9492","typ ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="20a1faeb-dc40-4f72-9bcc-ec0b65afb6a8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("20a1faeb-dc40-4f72-9bcc-ec0b65afb6a8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("20a1faeb-dc40-4f72-9bcc-ec0b65afb6a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '20a1faeb-dc40-4f72-9bcc-ec0b65afb6a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ff473916-c210-44f9-a46e-71658ba9c5bd":{"roots":{"references":[{"attributes":{"source":{"id":"79a3b141-fe6c-4d82-967b-72b970cfa5f7","type":"ColumnDataSource"}},"id":"a74673e1-1e3d-4c16-8bd7-20ab5ff3db18","type":"CDSView"},{"attributes":{},"id":"89a8eb6a-55cd-4b45-ade4-66b00ecef68f","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7ff5a58d-4060-4311-b87a-d48a8a4b0380","type":"PanTool"},{"id":"89a8eb6a-55cd-4b45-ade4-66b00ecef68f","type":"WheelZoomTool"},{"id":"69dab29b-c72f-46bc-a458-c1dee7c85afb","type":"BoxZoomTool"},{"id":"e38ed7c9-76cc-4641-825b-98faa0f9f372","type":"SaveTool"},{"id":"84ee241a-069f-458b-af1d-ae71bcdf1289","type":"ResetTool"},{"id":"203d6a21-543b-4f38-a299-89a9c719ec42","type":"HelpTool"}]},"id":"af264992-20eb-48b8-8a44-8c6419e28fbf","type":"Toolbar"},{"attributes":{"bottom":{"expr":{"id":"11079874-9a15-4315-aa76-216bb48ffcdb","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"c3626c39-7fab-40dc-91d1-c6d35d6aca26","type":"Stack"}},"width":{"value":0.5},"x":{"field":"cat"}},"id":"bea641a8-4f0e-432d-ba4d-5511ed140d16","type":"VBar"},{"attributes":{"overlay":{"id":"897c2a34-de65-4411-a7d4-0a7631a644dd","type":"BoxAnnotation"}},"id":"69dab29b-c72f-46bc-a458-c1dee7c85afb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"829fd8d5-801b-4d7e-b546-d074d1a12a8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3107d3b9-c580-44c4-9bc2-527d5cd83500","type":"BasicTicker"}},"id":"ead6c442-5a9a-4488-9c66-e63d5d883a4e","type":"Grid"},{"attributes":{},"id":"203d6a21-543b-4f38-a299-89a9c719ec42","type":"HelpTool"},{"attributes":{"bottom":{"expr":{"id":"674b3b9f-0f6f-4a8f-9916-754d41f21d2a","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"3d1ac9be-5aa5-4dbd-a96f-79ca99c8db3d","type":"Stack"}},"width":{"value":0.5},"x":{"field":"cat"}},"id":"38aadaea-403d-4c44-b087-06dabde78731","type":"VBar"},{"attributes":{"data_source":{"id":"79a3b141-fe6c-4d82-967b-72b970cfa5f7","type":"ColumnDataSource"},"glyph":{"id":"ddfebe75-e8e8-4ca4-a0e6-0693cac74e71","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"38aadaea-403d-4c44-b087-06dabde78731","type":"VBar"},"selection_glyph":null,"view":{"id":"a74673e1-1e3d-4c16-8bd7-20ab5ff3db18","type":"CDSView"}},"id":"1d194fb3-3218-4ef9-96fd-3acb79d01480","type":"GlyphRenderer"},{"attributes":{},"id":"4088b88d-d363-48d9-9554-953b0201c2a1","type":"BasicTicker"},{"attributes":{"source":{"id":"79a3b141-fe6c-4d82-967b-72b970cfa5f7","type":"ColumnDataSource"}},"id":"9193b036-afb7-4e6b-a388-0d1a579fc2e5","type":"CDSView"},{"attributes":{"fields":["yes"]},"id":"c3626c39-7fab-40dc-91d1-c6d35d6aca26","type":"Stack"},{"attributes":{"below":[{"id":"507f7d30-6a8c-4b30-b1a1-4142751fc943","type":"LinearAxis"}],"left":[{"id":"3f6eeb50-128c-4a5b-8aed-15d9aecd7f4e","type":"LinearAxis"}],"plot_height":250,"plot_width":300,"renderers":[{"id":"507f7d30-6a8c-4b30-b1a1-4142751fc943","type":"LinearAxis"},{"id":"ead6c442-5a9a-4488-9c66-e63d5d883a4e","type":"Grid"},{"id":"3f6eeb50-128c-4a5b-8aed-15d9aecd7f4e","type":"LinearAxis"},{"id":"ff8273a0-1d1e-425c-a65c-5117d5818875","type":"Grid"},{"id":"897c2a34-de65-4411-a7d4-0a7631a644dd","type":"BoxAnnotation"},{"id":"e1fc69cb-e9b8-4250-811c-05147d83b195","type":"Legend"},{"id":"2a239214-de6f-48f1-92e4-c0605d2511a5","type":"GlyphRenderer"},{"id":"1d194fb3-3218-4ef9-96fd-3acb79d01480","type":"GlyphRenderer"}],"title":{"id":"f0ad77f2-0dc5-43f3-8cef-5c74df23866c","type":"Title"},"toolbar":{"id":"af264992-20eb-48b8-8a44-8c6419e28fbf","type":"Toolbar"},"x_range":{"id":"f354c8e5-f493-44c3-8d38-262473d8d290","type":"Range1d"},"x_scale":{"id":"bb489883-f4e3-460d-bda2-b3b4f6accdab","type":"LinearScale"},"y_range":{"id":"0399 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d877ef6e-20e2-494b-962e-ab73032d1f2f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d877ef6e-20e2-494b-962e-ab73032d1f2f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d877ef6e-20e2-494b-962e-ab73032d1f2f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd877ef6e-20e2-494b-962e-ab73032d1f2f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e3196073-8c77-4dcd-80b3-0ff2fe76fb8b":{"roots":{"references":[{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"d69a665b-197a-4f24-97f4-82f9094724ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6e2277b-8133-4b61-8f23-5cf4e98f3473","type":"BasicTicker"}},"id":"cfc194af-2efb-4e03-ae28-91ef3aad009c","type":"Grid"},{"attributes":{},"id":"757a4037-a235-4ed4-b683-5ab14125dc86","type":"HelpTool"},{"attributes":{"source":{"id":"2bc26199-c21c-47de-8ff1-31e38b9e928f","type":"ColumnDataSource"}},"id":"1f99866a-2028-4ded-bcc8-b302a7c47096","type":"CDSView"},{"attributes":{},"id":"3b8c5a1f-815e-4745-8a92-4b83125ec249","type":"ResetTool"},{"attributes":{"source":{"id":"2bc26199-c21c-47de-8ff1-31e38b9e928f","type":"ColumnDataSource"}},"id":"83ca0bae-fa79-4dca-bc51-b957bbfadc7a","type":"CDSView"},{"attributes":{"plot":null,"text":"Heart Disease"},"id":"248620fd-3ba8-47df-91b7-0331b8d9f69a","type":"Title"},{"attributes":{},"id":"d7c82c51-950f-42f7-bd0e-4be59f606424","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5f981bd3-c210-4d2a-9317-99b5f718606b","type":"PanTool"},{"id":"a9846882-ae12-47b1-860c-dc16d757e6eb","type":"WheelZoomTool"},{"id":"9474ee49-a8db-4ef2-a538-d4e4d3b0868e","type":"BoxZoomTool"},{"id":"958ea060-7721-49d3-a56b-75bbc34d1844","type":"SaveTool"},{"id":"3b8c5a1f-815e-4745-8a92-4b83125ec249","type":"ResetTool"},{"id":"757a4037-a235-4ed4-b683-5ab14125dc86","type":"HelpTool"}]},"id":"d38e671f-8296-44f8-80b3-bc826807a120","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["diabetes","yes","no"],"data":{"diabetes":[0,1],"no":[26,8],"yes":[13,7]}},"id":"2bc26199-c21c-47de-8ff1-31e38b9e928f","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"6166f844-6074-4450-aedc-266d44e73bd7","type":"LinearAxis"}],"left":[{"id":"681c544e-c513-4897-8dd1-2d0093ebc95e","type":"LinearAxis"}],"plot_height":250,"plot_width":300,"renderers":[{"id":"6166f844-6074-4450-aedc-266d44e73bd7","type":"LinearAxis"},{"id":"31ab5289-0a33-4d7f-b1b6-35776a198814","type":"Grid"},{"id":"681c544e-c513-4897-8dd1-2d0093ebc95e","type":"LinearAxis"},{"id":"cfc194af-2efb-4e03-ae28-91ef3aad009c","type":"Grid"},{"id":"4a70e803-1acf-469c-8234-12c885d7f8e5","type":"BoxAnnotation"},{"id":"9b27a568-b5ce-4cb4-8ae7-0772c587f7e3","type":"Legend"},{"id":"045dc08f-ae51-4fb7-ab7e-58ce5e55369b","type":"GlyphRenderer"},{"id":"ffec4430-c93b-485a-9fdd-46dc49cf7b1c","type":"GlyphRenderer"}],"title":{"id":"248620fd-3ba8-47df-91b7-0331b8d9f69a","type":"Title"},"toolbar":{"id":"d38e671f-8296-44f8-80b3-bc826807a120","type":"Toolbar"},"x_range":{"id":"8f536684-4e21-4d62-85dc-baeaabb69060","type":"Range1d"},"x_scale":{"id":"96a4de48-bd89-4cf2-be64-0c16fe271089","type":"LinearScale"},"y_range":{"id":"50005d08-5c53-4687-b835-f4b4106a5f31","type":"DataRange1d"},"y_scale":{"id":"d7c82c51-950f-42f7-bd0e-4be59f606424","type":"LinearScale"}},"id":"d69a665b-197a-4f24-97f4-82f9094724ae","subtype":"Figure","type":"Plot"},{"attributes":{"fields":["yes","no"]},"id":"1bce6e4d-4cbb-4652-b9c1-7483cdf1cc96","type":"Stack"},{"attributes":{"fields":["yes"]},"id":"9fa9fa5e-c433-42f5-b936-c528d838d4ef","type":"Stack"},{"attributes":{},"id":"958ea060-7721-49d3-a56b-75bbc34d1844","type":"SaveTool"},{"attributes":{"bottom":{"expr":{"id":"f4f216fc-84fe-436c-9ac2-078d3ab251be","type":"Stack"}},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"expr":{"id":"52637a33-2b16-4e9d-aad6-ea52a480381e","type":"Stack"}},"width":{"value":0.5},"x":{"field":"diabetes"}},"id":"64e77f1b-8910-46d9-b5de-57ae4931f58d","type":"VBar"},{"attributes":{},"id":"a51487f8-48a4-45cf-8c95-a66e06acfe96","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"yes "},"renderers":[{"id":"045dc08f-ae51-4fb7-ab7e-58ce5e55369b","type":"GlyphRenderer"}]},"id":"f4f9ef11-e1a0-4a4d-b315-20489d0fab60","ty ...
